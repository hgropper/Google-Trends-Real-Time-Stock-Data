# %%
import time

try:
    import subprocess
    from datetime import datetime
    import pandas as pd
    from pytrends.request import TrendReq
    import statistics
    import csv
    from csv import reader
    import threading
    import concurrent.futures
    import copy
    import os
    import winsound
    from nordvpn_switcher import initialize_VPN,rotate_VPN,terminate_VPN
except Exception as e:
    print(str(e))
    time.sleep(30)

    
class GoogleTrend:
    '''Holds data about the stock ticker symbol,
    change in the trend/price, current trend, previous trend,
    current price, previous price, number of top occurrences
    and reason for adding it to the list'''

    def __init__(self, tickerSymbol, trendPriceRelationship = None, 
                  currentTrend = None, previousTrend = None, currentPrice = None, 
                  previousPrice = None, topOccurrences = 0, reason = None, timeScanned = None):
        '''Initializing variables'''
        self.tickerSymbol = tickerSymbol
        self.trendPriceRelationship = trendPriceRelationship
        self.currentTrend = currentTrend
        self.previousTrend = previousTrend
        self.currentPrice = currentPrice
        self.previousPrice = previousPrice
        self.topOccurrences = topOccurrences
        self.reason = reason
        self.timeScanned = timeScanned
        
    def getTickerSymbol(self):
        '''Returns the ticker symbol'''
        return self.tickerSymbol
    
    def getTrendPriceRelationship(self):
        '''Returns the change in the trend
        over the change in the stock's price'''
        
        if self.currentTrend != 0 and self.previousTrend != 0 and self.previousPrice != 0 and self.currentPrice != 0:
            # incase there is no past trend or past price
            try:
                changeInTrend = float(self.currentTrend - self.previousTrend)
                changeInPrice = float(self.currentPrice - self.previousPrice)

                # update the changeInPrice to 0.001 
                # if it is equal to zero
                if changeInPrice == 0:
                    changeInPrice = 0.001

                return abs(round(changeInTrend/changeInPrice,3))

            except:

                return 'N/A'
        else:
            return 'N/A'
    
    def getCurrentTrend(self):
        '''Returns the current google trend rating'''
        return self.currentTrend
    
    def getPreviousTrend(self):
        '''Returns the previous google trend rating'''
        return self.previousTrend
    
    def getCurrentPrice(self):
        '''Returns the current price of the stock'''
        return self.currentPrice
    
    def getPreviousPrice(self):
        '''Returns the previous price of the stock'''
        return self.previousPrice
    
    def getTopOccurrences(self):
        '''Returns the number of top ocurrences'''
        return self.topOccurrences
    
    def getReason(self):
        '''Returns the reason for adding the stock to the list'''
        return self.reason
    
    def getTimeScanned(self):
        '''Returns the time the stock was scanned'''
        return self.timeScanned

    def setTrendPriceRelationship(self, relationship):
        '''Updates the change in the trend
        over the change in the stock's price'''
        self.trendPriceRelationship = relationship
        
    def setCurrentTrend(self, currentTrend):
        '''Updates the current google trend rating'''
        self.currentTrend = currentTrend
    
    def setPreviousTrend(self, previousTrend):
        '''Updates the previous google trend rating'''
        self.previousTrend = previousTrend
    
    def setCurrentPrice(self, currentPrice):
        '''Updates the current price of the stock'''
        self.currentPrice = currentPrice
    
    def setPreviousPrice(self, previousPrice):
        '''Updates the previous price of the stock'''
        self.previousPrice = previousPrice
        
    def setReason(self, reason):
        '''Sets the reason for adding the stock to the list'''
        self.reason = reason
        
    def setTimeScanned(self,time):
        '''Updates the current time the stock was scanned'''
        self.timeScanned = time
        
    def incrementTopOccurrences(self):
        '''Updates occurrence to a boolean value'''
        self.topOccurrences += 1
        
    def isTopOccurrence(self):
        '''Returns boolean value if top occurrence'''
        return self.topOccurrence
    
# TD AMERITRADE API FUNCTIONS
# logging in

def loginToTDAmeritrade():
    # TD Ameritrade's custom API # pip install td-ameritrade-python-api
    from td.client import TDClient

    # Create a new instance of the client 
    global td_client
    td_client = TDClient(client_id = '90YQDEZ5UFQYSTQWAHMAOO4IBOE0YOEP', redirect_uri = 'https://localhost', credentials_path = r'C:\Users\hgrop\Desktop\My Python Projects\GoogleTrendsStockAlerts\GoogleTrendsV5\Untitled-1')

    # Login to a new session
    # Do this later in the loop so there is no time out
    td_client.login()

# Finds the current ask price for the stock
def askPrice(stock): 
    data = (td_client.get_quotes(instruments = [stock]))
    data = (str(data).replace(':', ','))
    data = (data.split(','))
    index = 0
    for datas in data:
        if (" 'askPrice'" == datas):
            return float(data[index + 1])
        index += 1
    
def collectingStockTickers():
    
    print("Initializing program...")
    
    # Initializes a list of tickers we want to further
    # look into 
    tickersToSearch = []

    # open the csv file that contains all the ticker in the world
    with open('ALLSTOCKS.csv', 'r') as file:

        # read all the rows and store them in the rows variable
        rows = reader(file)

        # sets the counter to 0
        counter = 0

        # starts iterating through the rows
        for row in rows:

            # increments counter by one
            counter += 1

            # Assigned the proper index to the proper cloumn
            # values used when iterating through the rest of the rows
            # only runs to read the header
            if counter == 1:
                tickerIndex = row.index('Symbol')
                nameIndex = row.index('Name')
                priceIndex = row.index('Last Sale')
                percentChangeIndex = row.index('% Change')
                marketCapIndex = row.index('Market Cap')
                volumeIndex = row.index('Volume')

            # only runs on the second iteration 
            # the row before the headers
            if counter > 1:

                # in case we encounter any companies with
                # missing data (we ignore them)
                try:

                    '''CONDITION 1'''
                    # if market cap is less than one billion (small cap) 
                    # that's a one and 9 zeros
                    marketCap = float(row[marketCapIndex])
                    if marketCap < 500000000 and marketCap > 1000:

                        '''CONDITION 2'''
                        # checks to see if the previous day's price action
                        # was not a pump and dump scheme
                        # also checks for activity
                        percentChange = abs(float(row[percentChangeIndex].replace('%','')))
                        if percentChange < 400:

                            '''CONDITION 3'''
                            # checks price to make sure it is less than $8
                            price = float(row[priceIndex].replace('$',''))
                            if price < 10 and price > 0:

                                '''FINAL CONDITION'''
                                # if all conditions are met
                                # and it is not a derivative
                                ticker = row[tickerIndex]
                                if ticker.isalpha():
                                    # adds ticker to the list
                                    # of tickers to searchs
                                    tickersToSearch.append(ticker)

                except:
                    pass
    
    print("Program initialized.")
    print("Found " + str(len(tickersToSearch)) + " tickers!\n")
    
    return tickersToSearch

def mean(data):
    '''Finds the mean of a list'''
    if len(data) > 1:
        
        sum = 0
        
        for element in data:
            sum += element
            
        return float(round((sum / len(data)),2))
    
    else:
        return data[0]

def splitList(dataList):
    '''Splits a list into two separate parts'''
    
    if len(dataList) > 1:
        
        # initialize variables
        firstHalf = []
        secondHalf = []
        counter = 0

        # if the length of the list is odd
        if len(dataList) % 2 == 1:
            dataList.pop(0)
            
        halfWayMark = int(len(dataList) / 2)
            
        return dataList[:halfWayMark], dataList[halfWayMark:]
    
def trendSearch(tickerToSearch, pytrends):

    # creating payload
    pytrends.build_payload([(tickerToSearch + " stock")], cat=0, timeframe = 'now 1-d')
    data = pytrends.interest_over_time()
    
    # converting trends data to a readable list
    data = data.values.tolist()
    
    return data, tickerToSearch

def dataCleanup(data):
    '''Cleans the data for later use'''
    
    # Initializing an empty google data trends list
    googleTrendsData = []

    # iterating through the google trends data
    for popularityScore in data:
        
        googleTrendsData.append(popularityScore[0])
    
    return googleTrendsData
    
def splitListIntoSections(data, sections):
    '''Splits a list into groups of 10s'''
    
    newList = []
    tempList = []
    
    for element in data:
        
        tempList.append(element)
        
        if len(tempList) >= sections:
            newList.append(tempList)
            tempList = []        
    
    if len(tempList) > 0:
        newList.append(tempList)
        
    return newList

def sortData():
    '''Sort stock data from highest
    variance to the least variance'''
    
    blacklist = ['RAM','ASM','BEST','ONE','UK','FORD','JOB','CAP',
                 'FORD','VERY','LIFE','AGE','GAME','TOUR','EARN','LOAN',
                 'NBA','VS','AUTO','NEW']
    
    unsortedData = []
    sortedData = []
    copyOfStockData = copy.deepcopy(stockData)

    for stock in stockData:
        unsortedData.append(stock.getCurrentTrend())

    while len(unsortedData) != 0:
        maximum = 0
        index = -1
        for data in unsortedData:
            index += 1
            if data >= maximum:
                maximumIndex = index
                maximum = data
                
        sortedData.append(copyOfStockData[maximumIndex])
        unsortedData.pop(maximumIndex)
        copyOfStockData.pop(maximumIndex)
        

    return sortedData

def createObjects(innerElement):
    '''Searches the stock ticker and filters out bad data'''
    
    global stockNames
    
    try:
        # Getting data
        data, ticker = trendSearch(innerElement, TrendReq(hl='en-US', tz=360))
    except:
        return 'error'

    # getting the current time
    theTime = (currentTime()[0] + ":" + currentTime()[1])
    
    # incase there is no data (try block)
    try:
        # cleans data and removes unwanted columns
        cleanData = dataCleanup(data)
        
        # calculates mean of the daya
        meanOfData = mean(cleanData)
        
        # calculates the current trend over the mean of the entire data set
        result = round(cleanData[-1]/meanOfData,3)
        
        # gets the number of spikes in the data
        count30, count60, count90, count100 = catchChoppyData(cleanData)
        
        # determines if the data is worthy
        if result <= 1:
            reason = 'low result'
            result = 0
        elif cleanData.count(0) >= int(len(cleanData) - 3):
            reason = 'too many zeros'
            result = 0
        elif (count30 >= 15 or count60 >= 3 or count90 >= 2 or count100 == 1):
            reason = 'spiked data'
            result = 0
        elif cleanData[len(cleanData) - 5:].count(0) >= 2:
            reason = 'front zeros'
            result = 0
        else:
            reason = 'good!'
        
        
        
        if innerElement not in stockNames: 
            stockData.append(GoogleTrend(tickerSymbol = ticker, currentTrend = result, 
                                            reason = reason , timeScanned = theTime))
        # output to the console
        print("Scanned: " + ticker + " // Trend: " + str(result))
        
        stockNames.add(innerElement)
        
        
    except:
        # if there is no data then execute the following
        reason = 'no data'
        result = 0
        if innerElement not in stockNames:
            stockData.append(GoogleTrend(tickerSymbol = ticker, currentTrend = result, 
                                            reason = reason , timeScanned = theTime))
        stockNames.add(innerElement)
        
def modifyObjects(innerElement):
    '''Searches the stock ticker and filters out bad data then
    modifies the objects in the stockData list'''
    
    global stockData
    global td_client
    
    # finding index to modify
    index = -1
    
    # gets the index
    for stock in stockData:
        if innerElement == stockData[index].getTickerSymbol():
            break
        else:
            index += 1
            
    # if top occurrence
    if stockData[index].getTickerSymbol() in tickers[:15]:
        stockData[index].incrementTopOccurrences()

    try:
        # Getting data
        data, ticker = trendSearch(innerElement, TrendReq(hl='en-US', tz=360))
    except Exception as e:
        print(str(e))
        return 'error'

    # getting the current time
    theTime = (currentTime()[0] + ":" + currentTime()[1])
    
    # if it is a top occurrence check the price 
    # using the TD ameritrade API
    if stockData[index].getTopOccurrences() >= 2:
        stockData[index].setPreviousPrice(stockData[index].getCurrentPrice())
        stockData[index].setCurrentPrice(askPrice(stockData[index].getTickerSymbol()))
        
    # incase there is no data (try block)
    try:
        # cleans data and removes unwanted columns
        cleanData = dataCleanup(data)
        
        # calculates mean of the daya
        meanOfData = mean(cleanData)
        
        # calculates the current trend over the mean of the entire data set
        result = round(cleanData[-1]/meanOfData,3)
        
        # gets the number of spikes in the data
        count30, count60, count90, count100 = catchChoppyData(cleanData)
        
        # determines if the data is worthy
        if result <= 1:
            reason = 'low result'
            result = 0
        elif cleanData.count(0) >= int(len(cleanData) - 3):
            reason = 'too many zeros'
            result = 0
        elif (count30 >= 15 or count60 >= 3 or count90 >= 2 or count100 == 1):
            reason = 'spiked data'
            result = 0
        elif cleanData[len(cleanData) - 5:].count(0) >= 2 :
            reason = 'front zeros'
            result = 0
        else:
            reason = 'good!'
        
        # modifying object
        stockData[index].setPreviousTrend(stockData[index].getCurrentTrend())
        stockData[index].setCurrentTrend(result)
        stockData[index].setReason(reason)
        stockData[index].setTimeScanned(theTime)
        stockData[index].setTrendPriceRelationship(stockData[index].getTrendPriceRelationship())
        
        # output to the console
        print("Scanned: " + ticker + " // Trend: " + str(result))
        
        
    except:
        # if there is no data then execute the following
        reason = 'no data'
        result = 0
        
        # modifying object
        stockData[index].setPreviousTrend(stockData[index].getCurrentTrend())
        stockData[index].setCurrentTrend(result)
        stockData[index].setReason(reason)
        stockData[index].setTimeScanned(theTime)
        stockData[index].setTrendPriceRelationship(stockData[index].getTrendPriceRelationship())

def currentTime():
    '''Returns current time 
    hour, minute, second'''

    # datetime object containing current date and time
    now = datetime.now()
    
    todaysDate = str(now).split(" ")[0]
    parsedData = str(now).split(" ")[1].split(':')
    hour = parsedData[0]
    minute = parsedData[1]
    second = parsedData[2]
    militaryTime = (str(hour) + ':' + str(minute))

    return hour, minute, second, militaryTime, todaysDate

def findMinimumIndex(dataList):
    '''Finds a lists minimum data point index'''
    
    minimum = 100
    
    for data in dataList:
        
        if data < minimum:
            minimum = data
            
            
    return dataList.index(minimum), minimum
        
def catchChoppyData(dataList):
    '''Catches outliers and spikes inside data sets'''
    
    index = -1
    count30 = 0
    count60 = 0
    count90 = 0
    count100 = 0
    
    for _ in dataList:
        index += 1
        
        if dataList[index] + 30 <= dataList[index + 1]:
            count30 += 1
        if dataList[index] + 60 <= dataList[index + 1]:
            count60 += 1
        if dataList[index] + 90 <= dataList[index + 1]:
            count90 += 1
        if dataList[index] + 100 <= dataList[index + 1]:
            count100 += 1
            
        if index == len(dataList) - 2:
            return count30,count60,count90,count100
    
def displayData():
    '''Collects data from the stockData
    and creates a panda data frame from it'''
    
    stockData = sortData()
    
    df = {}

    valList = []
    for stock in stockData:
        valList.append(list(vars(stock).values()))

    columnHeaders = list(vars(stockData[0]).keys())
    for header in columnHeaders:
        firstItter = True
        for val in valList:
            if firstItter:
                df[header] = [val[columnHeaders.index(header)]]
                firstItter = False
            else:
                df[header] += [val[columnHeaders.index(header)]]
                
    return pd.DataFrame(df)
            

def main():
    '''Executes the whole program'''
    
    global stockDataFrame
    global stockData
    global tickers
    global td_client
    global tickers
    
    # starts the timer
    start = time.perf_counter()
    
    # keeps track of the number of scans (iterations)
    iteration = 0
    
    # current timeframe being used in google trends
    print("Using timeframe (" + 'now 1-d' + ")\n")
        
    # terminates VPN if cnnected
    try:
        terminate_VPN()
        print("...From the current VPN connection...\n")
        time.sleep(3)
    except:
        pass
    
    # After terminating VPN login to the TD ameritrade API client
    # do this everytime so there is no timeout
    loginToTDAmeritrade()
    
    # initializes VPN settings
    settings = initialize_VPN(save=1,area_input=['Canada','united states'])
    
    # rotate VPN
    rotate_VPN(settings)
        
    # collects tickers based off constraints
    tickers = collectingStockTickers()
    
    # if the stock data is already populated
    # then make a new tickers list with the 
    # most popular stocks in the front
    if len(stockData) == len(tickers):
        print("Multiple runs... modifying objects")
        tickers = copy.deepcopy([])
        for stock in sortData():
            tickers.append(stock.getTickerSymbol())
    
    # splits data into lists of 8 elements (I have possible 8 threads)
    dataList = splitListIntoSections(tickers, 8)
    
    # iterates through the split lists inside the "big" list
    for outterList in dataList:

        # if there is a BITCH error
        bitch = 0
        
        
        # if stock data is populated
        if len(stockData) == len(tickers):
            with concurrent.futures.ThreadPoolExecutor() as executor:
                dataToAdd = executor.map(modifyObjects,outterList)
        else:
            # in sets of specified sections
            with concurrent.futures.ThreadPoolExecutor() as executor:
                dataToAdd = executor.map(createObjects,outterList)

        # error handling
        for e in dataToAdd:
            if e == 'error' and bitch == 0:
                bitch = 1
                rotate_VPN(settings) 
                dataList.append(outterList)
                time.sleep(0.5)
                
        # every 3 scans pass the stockData to the kernel to be displayed
        # passes variable along to the kernel, so it can be used in
        # other notebook simultaneously
        iteration += 1
        if iteration % 3 == 0:
            stockDataFrame = displayData()
            # %store stockDataFrame
        
            
            
            
    # one last time after loop
    stockDataFrame = displayData()
    # %store stockDataFrame
            
    # Gets the current date and time
    timeStamp = ("-" + currentTime()[4] + "@" + currentTime()[3]).replace(':',"-")
    
    # gets the ending time
    end = time.perf_counter()
    
    # calculates the time in minutes from the start to end
    totalTimeInMinutes = round(((end - start)/60),2)
    
    # writing data to csv
    csvFileName = ('GoogleTrends' + timeStamp)
    stockDataFrame.to_csv(r'C:\Users\hgrop\Desktop\My Python Projects\GoogleTrendsStockAlerts\GoogleTrendsV5\ ' + str(csvFileName) + '.csv', index = False, header=True)
    
    # outputs to file
    print("\nThe program took " + str(totalTimeInMinutes) + " minutes to run.")
    
    # Turn the VPN off after completed scan 
    terminate_VPN()
    time.sleep(3)
            
    # short delay in between runs
    time.sleep(5)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1232

# %%
stockData = []
stockNames = set()

# %%
while True:
    try:
        main()
        time.sleep(10)
    except Exception as e:
        print(str(e))
# Out:
# Using timeframe (now 1-d)
#
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Disconnecting...
# Done!
# ...From the current VPN connection...
#
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Saving settings in project folder...
#
#
# Done!
#
#
# Your current ip-address is: 69.136.101.196
#
# Connecting you to united states ...
#
# your new ip-address is: 83.136.182.185
#
# Done! Enjoy your new server.
#
# Initializing program...
# Program initialized.
# Found 1736 tickers!
#
# Multiple runs... modifying objects
# Scanned: VSTM // Trend: 0
# Scanned: THMO // Trend: 8.214
# Scanned: DYAI // Trend: 4.684
# Scanned: ATER // Trend: 1.283
# Scanned: LYRA // Trend: 16.136
# Scanned: LITB // Trend: 23.981
# Scanned: BRQS // Trend: 1.418
# Scanned: TACO // Trend: 0
# Scanned: UGRO // Trend: 0
# Scanned: IDRA // Trend: 0
# Scanned: IFRX // Trend: 0
# Scanned: UK // Trend: 1.049
# Scanned: UNAM // Trend: 0
# Scanned: UNCY // Trend: 0
# Scanned: UFAB // Trend: 0
# Scanned: UONE // Trend: 0
# Scanned: ULBI // Trend: 0
# Scanned: SAII // Trend: 0
# Scanned: SREV // Trend: 0
# Scanned: UIHC // Trend: 0
# Scanned: SRT // Trend: 0
# Scanned: SANW // Trend: 0
# Scanned: SACH // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: PSTV // Trend: 0
# Scanned: OPTT // Trend: 0
# Scanned: OPT // Trend: 0
# Scanned: ORGS // Trend: 0
# Scanned: ORN // Trend: 0
# Scanned: ORPH // Trend: 2.753
# Scanned: OPTN // Trend: 0
# Scanned: NCMI // Trend: 0
# Scanned: MACQ // Trend: 0
# Scanned: NEON // Trend: 0
# Scanned: NCNA // Trend: 0
# Scanned: NDRA // Trend: 0
# Scanned: MAGS // Trend: 0
# Scanned: MARK // Trend: 0
# Scanned: KLR // Trend: 0
# Scanned: KLDO // Trend: 0
# Scanned: KIN // Trend: 0
# Scanned: KINS // Trend: 0
# Scanned: KIQ // Trend: 0
# Scanned: MACK // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: IDN // Trend: 0
# Scanned: ATY // Trend: 0
# Scanned: AMPY // Trend: 0
# Scanned: AMTX // Trend: 0
# Scanned: ATNM // Trend: 0
# Scanned: ARTW // Trend: 0
# Scanned: AMST // Trend: 0
# Scanned: ZSAN // Trend: 0
# Scanned: ZKIN // Trend: 0
# Scanned: ZVO // Trend: 0
# Scanned: ZTR // Trend: 0
# Scanned: ZIVO // Trend: 0
# Scanned: AMS // Trend: 0
# Scanned: ZYNE // Trend: 0
# Scanned: ZIXI // Trend: 0
# Scanned: YQ // Trend: 0
# Scanned: YRD // Trend: 0
# Scanned: ZIOP // Trend: 0
# Scanned: ZEV // Trend: 0
# Scanned: YVR // Trend: 0
# Scanned: ZCMD // Trend: 0
# Scanned: YTRA // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: XYF // Trend: 0
# Scanned: YTEN // Trend: 0
# Scanned: YMTX // Trend: 0
# Scanned: YGMZ // Trend: 0
# Scanned: YELL // Trend: 0
# Scanned: YJ // Trend: 0
# Scanned: YCBD // Trend: 0
# Scanned: XPDI // Trend: 0
# Scanned: XIN // Trend: 0
# Scanned: XPOA // Trend: 0
# Scanned: XTNT // Trend: 0
# Scanned: XTLB // Trend: 0
# Scanned: XSPA // Trend: 0
# Scanned: XPL // Trend: 0
# Scanned: XNET // Trend: 0
# Scanned: XELB // Trend: 0
# Scanned: XCUR // Trend: 0
# Scanned: XFLT // Trend: 0
# Scanned: XELA // Trend: 1.804
# Scanned: XFOR // Trend: 0
# Scanned: WYY // Trend: 0
# Scanned: XERS // Trend: 0
# Scanned: XBIO // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: WTER // Trend: 0
# Scanned: WSR // Trend: 0
# Scanned: WWR // Trend: 0
# Scanned: WTRH // Trend: 2.08
# Scanned: WTT // Trend: 0
# Scanned: WRN // Trend: 0
#
# Your current ip-address is: 83.136.182.185
#
# Connecting you to united states ...
#
# your new ip-address is: 185.207.249.20
#
# Done! Enjoy your new server.
#
# Scanned: WMC // Trend: 0
# Scanned: WNW // Trend: 0
# Scanned: WVE // Trend: 0
# Scanned: WNEB // Trend: 0
# Scanned: WLMS // Trend: 0
# Scanned: WPG // Trend: 0
# Scanned: WORX // Trend: 0
# Scanned: WKEY // Trend: 0
# Scanned: WIMI // Trend: 0
# Scanned: WATT // Trend: 0
# Scanned: WISA // Trend: 0
# Scanned: WINT // Trend: 0
# Scanned: WAVE // Trend: 0
# Scanned: WHLR // Trend: 0
# Scanned: WEI // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: VYNE // Trend: 0
# Scanned: VTVT // Trend: 0
# Scanned: VYNT // Trend: 0
# Scanned: WHLM // Trend: 5.066
# Scanned: VYGR // Trend: 0
# Scanned: WALD // Trend: 0
# Scanned: VVOS // Trend: 0
# Scanned: VVPR // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: WAFU // Trend: 0
# Scanned: VRPX // Trend: 0
# Scanned: VTSI // Trend: 0
#
# Your current ip-address is: 185.207.249.20
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.213.14
#
# Done! Enjoy your new server.
#
# Scanned: VOSO // Trend: 0
# Scanned: VRNA // Trend: 0
# Scanned: VRME // Trend: 0
# Scanned: VNTR // Trend: 0
# Scanned: VPCC // Trend: 0
# Scanned: VPCB // Trend: 0
# Scanned: VOLT // Trend: 0
# Scanned: VOC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: VMD // Trend: 0
# Scanned: VKTX // Trend: 0
# Scanned: VLON // Trend: 0
# Scanned: VMAR // Trend: 0
# Scanned: VNCE // Trend: 0
# Scanned: VNRX // Trend: 0
# Scanned: VIOT // Trend: 0
# Scanned: VIST // Trend: 0
# Scanned: VISL // Trend: 0
# Scanned: VIVE // Trend: 0
# Scanned: VIRI // Trend: 0
# Scanned: VJET // Trend: 0
# Scanned: VINO // Trend: 0
# Scanned: VGZ // Trend: 0
# Scanned: VII // Trend: 0
# Scanned: VERY // Trend: 0
# Scanned: VIH // Trend: 0
# Scanned: VHAQ // Trend: 0
# Scanned: VEV // Trend: 0
# Scanned: VHC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: VELO // Trend: 0
# Scanned: VEEE // Trend: 0
# Scanned: VCNX // Trend: 0
# Scanned: VERO // Trend: 0
# Scanned: VERB // Trend: 0
# Scanned: VENA // Trend: 0
# Scanned: VECT // Trend: 0
# Scanned: UUU // Trend: 0
# Scanned: UTSI // Trend: 0
# Scanned: UTME // Trend: 0
# Scanned: USWS // Trend: 0
# Scanned: VACQ // Trend: 0
# Scanned: USX // Trend: 0
# Scanned: UTI // Trend: 0
# Scanned: VBLT // Trend: 0
# Scanned: USIO // Trend: 0
# Scanned: UONEK // Trend: 0
# Scanned: USDP // Trend: 0
# Scanned: USEG // Trend: 0
# Scanned: URG // Trend: 0
# Scanned: UPC // Trend: 0
# Scanned: UROY // Trend: 0
# Scanned: USAS // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: UBX // Trend: 0
# Scanned: UAVS // Trend: 0
# Scanned: TYME // Trend: 0
# Scanned: UCL // Trend: 0
# Scanned: UAMY // Trend: 0
# Scanned: UEPS // Trend: 0
# Scanned: TYHT // Trend: 0
# Scanned: TXMD // Trend: 0
# Scanned: TWND // Trend: 0
# Scanned: TWOA // Trend: 0
# Scanned: TURN // Trend: 1.537
# Scanned: TUSK // Trend: 0
# Scanned: TSI // Trend: 0
# Scanned: TUEM // Trend: 0
# Scanned: TTNP // Trend: 0
# Scanned: TTOO // Trend: 0
# Scanned: TTSH // Trend: 0
# Scanned: TTI // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: TRIB // Trend: 0
# Scanned: TRX // Trend: 0
# Scanned: TRT // Trend: 0
# Scanned: TRIT // Trend: 0
# Scanned: TRVI // Trend: 0
# Scanned: TRKA // Trend: 0
# Scanned: TRVN // Trend: 0
# Scanned: TNP // Trend: 0
# Scanned: TNXP // Trend: 0
# Scanned: TREC // Trend: 0
# Scanned: TMQ // Trend: 0
# Scanned: TOPS // Trend: 0
# Scanned: TOMZ // Trend: 0
# Scanned: TOUR // Trend: 0
# Scanned: TPHS // Trend: 0
# Scanned: TMAC // Trend: 0
# Scanned: TLGT // Trend: 0
# Scanned: TMBR // Trend: 0
# Scanned: TLSA // Trend: 0
# Scanned: TMDI // Trend: 0
# Scanned: TLMD // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: TK // Trend: 0
# Scanned: TIPT // Trend: 0
#
# Your current ip-address is: 37.19.213.14
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.128
#
# Done! Enjoy your new server.
#
# Scanned: TH // Trend: 0
# Scanned: THM // Trend: 0
# Scanned: THMA // Trend: 0
# Scanned: TENX // Trend: 0
# Scanned: TFFP // Trend: 0
# Scanned: TGA // Trend: 0
# Scanned: THTX // Trend: 0
# Scanned: TCDA // Trend: 0
# Scanned: TEI // Trend: 0
# Scanned: TERN // Trend: 0
# Scanned: TESS // Trend: 0
# Scanned: TEDU // Trend: 0
# Scanned: TCON // Trend: 0
# Scanned: TBLT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: TATT // Trend: 0
# Scanned: TARA // Trend: 0
# Scanned: TAST // Trend: 0
# Scanned: TANH // Trend: 0
# Scanned: SYN // Trend: 0
# Scanned: TAOP // Trend: 0
# Scanned: TC // Trend: 1.681
# Scanned: SYRS // Trend: 0
# Scanned: SWBK // Trend: 0
# Scanned: SYBX // Trend: 0
# Scanned: SYPR // Trend: 0
# Scanned: SYTA // Trend: 0
# Scanned: SWET // Trend: 0
# Scanned: TAIT // Trend: 0
# Scanned: SVT // Trend: 0
# Scanned: SXTC // Trend: 0
# Scanned: SVRA // Trend: 0
# Scanned: SVOK // Trend: 0
# Scanned: SUNW // Trend: 0
# Scanned: SWZ // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: SUPV // Trend: 0
# Scanned: SURF // Trend: 0
# Scanned: SUP // Trend: 0
# Scanned: SVFD // Trend: 0
# Scanned: STPC // Trend: 0
# Scanned: STWO // Trend: 0
# Scanned: STRM // Trend: 0
# Scanned: SSKN // Trend: 0
# Scanned: STSA // Trend: 0
# Scanned: STIM // Trend: 0
# Scanned: STON // Trend: 0
# Scanned: STKS // Trend: 0
# Scanned: SSY // Trend: 0
# Scanned: STRR // Trend: 0
# Scanned: SSNT // Trend: 0
# Scanned: SRTS // Trend: 0
# Scanned: SRGA // Trend: 0
# Scanned: SQFT // Trend: 0
# Scanned: STCN // Trend: 0
# Scanned: STAF // Trend: 0
# Scanned: STG // Trend: 0
# Scanned: SSAA // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: SQBG // Trend: 0
# Scanned: SPRB // Trend: 0
# Scanned: SRAX // Trend: 0
# Scanned: SRSA // Trend: 0
# Scanned: SPOK // Trend: 0
# Scanned: SQNS // Trend: 0
# Scanned: SPRT // Trend: 0
# Scanned: SPTK // Trend: 0
# Scanned: SPI // Trend: 0
# Scanned: SPGS // Trend: 0
# Scanned: SONN // Trend: 0
# Scanned: SOLO // Trend: 0
# Scanned: SPCB // Trend: 0
# Scanned: SPFR // Trend: 0
# Scanned: SOS // Trend: 0
# Scanned: SOFIW // Trend: 0
# Scanned: SOAC // Trend: 0
# Scanned: SOHO // Trend: 0
# Scanned: SOL // Trend: 0
# Scanned: SONM // Trend: 2.741
# Scanned: SOI // Trend: 0
# Scanned: SNPR // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: SND // Trend: 0
# Scanned: SNOA // Trend: 0
# Scanned: SNTG // Trend: 0
# Scanned: SNSE // Trend: 0
# Scanned: SNPX // Trend: 0
# Scanned: SNCR // Trend: 0
# Scanned: SNES // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 37.19.212.128
#
# Connecting you to united states ...
#
# your new ip-address is: 83.136.182.53
#
# Done! Enjoy your new server.
#
# Scanned: SLS // Trend: 0
# Scanned: SLAC // Trend: 0
# Scanned: SMED // Trend: 0
# Scanned: SMHI // Trend: 0
# Scanned: SJT // Trend: 0
# Scanned: SLNO // Trend: 0
# Scanned: SLDB // Trend: 0
# Scanned: SLHG // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: SLNG // Trend: 0
# Scanned: SIEB // Trend: 0
# Scanned: SINT // Trend: 0
# Scanned: SLGG // Trend: 0
# Scanned: SIGA // Trend: 0
# Scanned: SHIP // Trend: 1.808
# Scanned: SINO // Trend: 0
# Scanned: SGTX // Trend: 0
# Scanned: SIOX // Trend: 0
# Scanned: SJ // Trend: 0
# Scanned: SGBX // Trend: 0
# Scanned: SIEN // Trend: 0
# Scanned: SGRP // Trend: 0
# Scanned: SFTW // Trend: 0
# Scanned: SGMA // Trend: 0
# Scanned: SELF // Trend: 0Scanned: SGLB // Trend: 0
#
# Scanned: SECO // Trend: 0
# Scanned: SEEL // Trend: 0
# Scanned: SFET // Trend: 0
# Scanned: SDH // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: SELB // Trend: 0
# Scanned: SDPI // Trend: 0
# Scanned: SCPS // Trend: 0
# Scanned: SEAC // Trend: 0
# Scanned: SCVX // Trend: 0
# Scanned: SCPH // Trend: 0
# Scanned: SCX // Trend: 0
# Scanned: SFE // Trend: 0
# Scanned: SCPE // Trend: 1.386
# Scanned: SCOR // Trend: 0
# Scanned: SCYX // Trend: 0
# Scanned: SD // Trend: 0
# Scanned: SBT // Trend: 0
# Scanned: RYB // Trend: 0
# Scanned: SB // Trend: 0
# Scanned: SBET // Trend: 0
# Scanned: SALM // Trend: 0
# Scanned: SCKT // Trend: 0
# Scanned: SBI // Trend: 0
# Scanned: SBEV // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: SBBP // Trend: 0
# Scanned: RVSB // Trend: 0
# Scanned: RSLS // Trend: 0
# Scanned: RWLK // Trend: 0
# Scanned: RSSS // Trend: 0
# Scanned: RVPH // Trend: 0
# Scanned: RYAM // Trend: 0
# Scanned: RNGR // Trend: 0
# Scanned: RPHM // Trend: 0
# Scanned: RNAZ // Trend: 0
# Scanned: ROT // Trend: 0
# Scanned: RNWK // Trend: 0
# Scanned: RRD // Trend: 0
# Scanned: RSVR // Trend: 0
# Scanned: ROSS // Trend: 0
# Scanned: RMCF // Trend: 0
# Scanned: RMED // Trend: 0
# Scanned: ROCR // Trend: 0
# Scanned: RMTI // Trend: 0
# Scanned: RMGB // Trend: 0
# Scanned: RKDA // Trend: 0
# Scanned: RLGT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: RGC // Trend: 0
# Scanned: RESN // Trend: 0
# Scanned: RFIL // Trend: 0
# Scanned: RGLS // Trend: 0
# Scanned: RIBT // Trend: 0
# Scanned: RETO // Trend: 0
# Scanned: RGS // Trend: 0
# Scanned: RHE // Trend: 0
# Scanned: REFR // Trend: 0
# Scanned: REKR // Trend: 0
# Scanned: REPH // Trend: 0
# Scanned: RELL // Trend: 0
# Scanned: RELI // Trend: 0
# Scanned: REED // Trend: 0
# Scanned: REI // Trend: 0
# Scanned: REDU // Trend: 0
# Scanned: RCON // Trend: 0
# Scanned: RCS // Trend: 0
# Scanned: RDI // Trend: 0
# Scanned: RCLF // Trend: 0
# Scanned: RCMT // Trend: 0
# Scanned: RDHL // Trend: 0
# Scanned: REAX // Trend: 0
# Scanned: RCRT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 83.136.182.53
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.143
#
# Done! Enjoy your new server.
#
# Scanned: QUAD // Trend: 0
# Scanned: QTT // Trend: 0
# Scanned: QLI // Trend: 0
# Scanned: QMCO // Trend: 0
# Scanned: QUIK // Trend: 0
# Scanned: QUBT // Trend: 0
# Scanned: QUMU // Trend: 0
# Scanned: QRHC // Trend: 0
# Scanned: QH // Trend: 0
# Scanned: QELL // Trend: 0
# Scanned: PZG // Trend: 0
# Scanned: QK // Trend: 0
# Scanned: QTNT // Trend: 0
# Scanned: QIPT // Trend: 0
# Scanned: QD // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: QLGN // Trend: 0
# Scanned: PXLW // Trend: 0
# Scanned: PYPD // Trend: 0
# Scanned: PXS // Trend: 0
# Scanned: PUCK // Trend: 0
# Scanned: PVL // Trend: 0
# Scanned: PWFL // Trend: 0
# Scanned: PULM // Trend: 0
# Scanned: PTPI // Trend: 0
# Scanned: PTIX // Trend: 0
# Scanned: PTN // Trend: 0
# Scanned: PTMN // Trend: 0
# Scanned: PTRS // Trend: 0
# Scanned: PSTX // Trend: 0
# Scanned: PTE // Trend: 0
# Scanned: PSTI // Trend: 0
# Scanned: PTK // Trend: 0
# Scanned: PSHG // Trend: 0
# Scanned: PT // Trend: 1.755
# Stored 'stockDataFrame' (DataFrame)
# Scanned: PRT // Trend: 0
# Scanned: PRFX // Trend: 0
# Scanned: PRQR // Trend: 0
# Scanned: PRPH // Trend: 0
# Scanned: PRTK // Trend: 0
# Scanned: PRTH // Trend: 0
# Scanned: PRPO // Trend: 0
# Scanned: PRVB // Trend: 0
# Scanned: PPSI // Trend: 0
# Scanned: PPTA // Trend: 0
# Scanned: PPT // Trend: 0
# Scanned: POND // Trend: 0
# Scanned: PPBT // Trend: 0
# Scanned: PPIH // Trend: 0
# Scanned: PROG // Trend: 0
# Scanned: PNNT // Trend: 0
# Scanned: PME // Trend: 0
# Scanned: POAI // Trend: 0
# Scanned: PNBK // Trend: 0
# Scanned: POW // Trend: 0
# Scanned: POLA // Trend: 0
# Scanned: PNT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: PMM // Trend: 0
# Scanned: PICC // Trend: 0
# Scanned: PLM // Trend: 0
# Scanned: PMD // Trend: 0
# Scanned: PMBC // Trend: 0
# Scanned: PLX // Trend: 0
# Scanned: PLIN // Trend: 0
# Scanned: PLAG // Trend: 0
# Scanned: PIAI // Trend: 0
# Scanned: PHUN // Trend: 0
# Scanned: PIM // Trend: 0
# Scanned: PLG // Trend: 0
# Scanned: PIRS // Trend: 0
# Scanned: PIXY // Trend: 3.184
# Scanned: PIPP // Trend: 0
# Scanned: PHAS // Trend: 0
# Scanned: PHIO // Trend: 0
# Scanned: PHT // Trend: 0
# Scanned: PEI // Trend: 0
# Scanned: PHGE // Trend: 0
# Scanned: PHX // Trend: 0
# Scanned: PHCF // Trend: 0
# Scanned: PHIC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: PFIE // Trend: 0
# Scanned: PESI // Trend: 0
# Scanned: PFMT // Trend: 0
# Scanned: PCF // Trend: 0
# Scanned: PETZ // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: PCSA // Trend: 0
# Scanned: PCTI // Trend: 0
#
# Your current ip-address is: 37.19.212.143
#
# Connecting you to united states ...
#
# your new ip-address is: 185.207.249.67
#
# Done! Enjoy your new server.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 185.207.249.67
#
# Connecting you to canada ...
#
# your new ip-address is: 162.253.71.39
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: OXBR // Trend: 0
# Scanned: OXSQ // Trend: 0
# Scanned: OSI // Trend: 0
# Scanned: PANA // Trend: 0
# Scanned: PACX // Trend: 0
# Scanned: OTIC // Trend: 0
# Scanned: OVID // Trend: 0
# Scanned: OTLK // Trend: 0
# Scanned: ORTX // Trend: 0
# Scanned: OSS // Trend: 0
# Scanned: OSN // Trend: 0
# Scanned: OPHC // Trend: 0
# Scanned: OSG // Trend: 0
# Scanned: OSMT // Trend: 0
# Scanned: OSAT // Trend: 0
# Scanned: OPGN // Trend: 0
# Scanned: ONDS // Trend: 0
# Scanned: ONCY // Trend: 0
# Scanned: ONTX // Trend: 0
# Scanned: ONVO // Trend: 0
# Scanned: OPA // Trend: 0
# Scanned: ONE // Trend: 1.224
# Scanned: ONCT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: OMEX // Trend: 0
# Scanned: OIIM // Trend: 0
# Scanned: OIS // Trend: 0
# Scanned: OLB // Trend: 0
# Scanned: ONCS // Trend: 0
# Scanned: OIA // Trend: 0
# Scanned: OGEN // Trend: 0
# Scanned: OFS // Trend: 0
# Scanned: OESX // Trend: 0
# Scanned: OEG // Trend: 0
# Scanned: ODT // Trend: 0
# Scanned: OCX // Trend: 0
# Scanned: OG // Trend: 0
# Scanned: OCUP // Trend: 0
# Scanned: OCG // Trend: 0
# Scanned: NYMX // Trend: 0
# Scanned: OBLG // Trend: 0
# Scanned: OCA // Trend: 0
# Scanned: OCC // Trend: 0
# Scanned: OBSV // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: NXTP // Trend: 0
# Scanned: NXTD // Trend: 1.222
# Scanned: NVOS // Trend: 0
# Scanned: NVIV // Trend: 0
# Scanned: NXTC // Trend: 0
# Scanned: NWHM // Trend: 0
# Scanned: NTWK // Trend: 0
# Scanned: NUZE // Trend: 0
# Scanned: NUWE // Trend: 0
# Scanned: NVCN // Trend: 0
# Scanned: NVFY // Trend: 0
# Scanned: NSH // Trend: 0
# Scanned: NSPR // Trend: 0
# Scanned: NRT // Trend: 0
# Scanned: NRO // Trend: 0
# Scanned: NRBO // Trend: 0
# Scanned: NSL // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: NMTR // Trend: 0
# Scanned: NOVN // Trend: 0
# Scanned: NPTN // Trend: 0
# Scanned: NNBR // Trend: 0
# Scanned: NR // Trend: 0
# Scanned: NNA // Trend: 0
# Scanned: NOAC // Trend: 0
# Scanned: NNVC // Trend: 0
# Scanned: NLTX // Trend: 0
# Scanned: NML // Trend: 0
# Scanned: NLSP // Trend: 0
# Scanned: NMTC // Trend: 0
# Scanned: NMRD // Trend: 0
# Scanned: NMG // Trend: 0
# Scanned: NM // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: NGCA // Trend: 0
# Scanned: NISN // Trend: 0
# Scanned: NHTC // Trend: 0
# Scanned: NGS // Trend: 0
#
# Your current ip-address is: 162.253.71.39
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.143
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: NEXT // Trend: 0
# Scanned: NERV // Trend: 0
# Scanned: NEPT // Trend: 0
# Scanned: NGAC // Trend: 0
# Scanned: NEW // Trend: 1.518
# Scanned: NEPH // Trend: 0
# Scanned: NES // Trend: 0
# Scanned: NGC // Trend: 0
# Scanned: NBY // Trend: 0
# Scanned: NBSE // Trend: 0
# Scanned: NAOV // Trend: 0
# Scanned: NAK // Trend: 0
# Scanned: NAT // Trend: 0
# Scanned: NBEV // Trend: 0
# Scanned: NCZ // Trend: 0
# Scanned: MYO // Trend: 0
# Scanned: MVO // Trend: 0
# Scanned: NBRV // Trend: 0
# Scanned: NAKD // Trend: 1.12
# Scanned: MTP // Trend: 0
# Scanned: MTR // Trend: 0
# Scanned: NAVB // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: MYMD // Trend: 0
# Scanned: MTBC // Trend: 0
# Scanned: MXC // Trend: 0
# Scanned: MSN // Trend: 1.733
# Scanned: MYSZ // Trend: 0
# Scanned: MTNB // Trend: 0
# Scanned: MTC // Trend: 0
# Scanned: MTCR // Trend: 0
# Scanned: MTAC // Trend: 0
# Scanned: MTA // Trend: 0
# Scanned: MRAM // Trend: 0
# Scanned: MRKR // Trend: 0
# Scanned: MTEM // Trend: 0
# Scanned: MSD // Trend: 0
# Scanned: MRIN // Trend: 0
# Scanned: MRM // Trend: 0
# Scanned: MOHO // Trend: 0
# Scanned: MON // Trend: 0
# Scanned: MREO // Trend: 0
# Scanned: MRAC // Trend: 0
# Scanned: MOSY // Trend: 0
# Scanned: MOVE // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: MOTS // Trend: 0
# Scanned: MNPR // Trend: 0
# Scanned: MPAC // Trend: 0
# Scanned: MNTX // Trend: 0
# Scanned: MMMB // Trend: 0
# Scanned: MOGU // Trend: 0
# Scanned: MMT // Trend: 0
# Scanned: MNDO // Trend: 0
# Scanned: MN // Trend: 0
# Scanned: MNOV // Trend: 0
# Scanned: MITQ // Trend: 0
# Scanned: MLAC // Trend: 0
# Scanned: MOGO // Trend: 1.38
# Scanned: MKD // Trend: 0
# Scanned: MKTY // Trend: 0
# Scanned: MMLP // Trend: 0
# Scanned: MITC // Trend: 0
# Scanned: MLSS // Trend: 0
# Scanned: MIST // Trend: 0
# Scanned: MHLD // Trend: 0
# Scanned: MICT // Trend: 0
# Scanned: MINM // Trend: 0
# Scanned: MITO // Trend: 0
# Scanned: MIN // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: MGTA // Trend: 0
# Scanned: MIND // Trend: 0
# Scanned: MFM // Trend: 0
# Scanned: METC // Trend: 0
# Scanned: MFD // Trend: 0
# Scanned: MFIN // Trend: 0
# Scanned: MESA // Trend: 0
# Scanned: METX // Trend: 0
# Scanned: MEDS // Trend: 0
# Scanned: MDRR // Trend: 0
# Scanned: MDNA // Trend: 0
# Scanned: MFH // Trend: 0
# Scanned: MDVL // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: MCBC // Trend: 0
#
# Your current ip-address is: 37.19.212.143
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.98
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: MDIA // Trend: 1.31
# Scanned: MCHX // Trend: 0
# Scanned: MCAE // Trend: 0
# Scanned: MDH // Trend: 0
# Scanned: MBIO // Trend: 0
# Scanned: MBOT // Trend: 0
# Scanned: MARPS // Trend: 0
# Scanned: MBTC // Trend: 0
# Scanned: MBII // Trend: 0
# Scanned: MBRX // Trend: 0
# Scanned: MACA // Trend: 0
# Scanned: LXU // Trend: 0
# Scanned: LYL // Trend: 0
# Scanned: LUB // Trend: 0
# Scanned: LWAY // Trend: 0
# Scanned: LVTX // Trend: 0
# Scanned: LYTS // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: LUMO // Trend: 0
# Scanned: LTBR // Trend: 0
# Scanned: LTRPA // Trend: 0
# Scanned: LTRX // Trend: 0
# Scanned: LSEA // Trend: 0
# Scanned: LUXA // Trend: 0
# Scanned: LPTX // Trend: 0
# Scanned: LOV // Trend: 0
# Scanned: LOGC // Trend: 0
# Scanned: LPCN // Trend: 0
# Scanned: LQDA // Trend: 0
# Scanned: LND // Trend: 0
# Scanned: LODE // Trend: 0
# Scanned: LPTH // Trend: 0
# Scanned: LOKB // Trend: 0
# Scanned: LMB // Trend: 0
# Scanned: LMFA // Trend: 0
# Scanned: LOAN // Trend: 3.106
# Scanned: LMNL // Trend: 0
# Scanned: LJPC // Trend: 0
# Scanned: LKCO // Trend: 3.909
# Stored 'stockDataFrame' (DataFrame)
# Scanned: LLNW // Trend: 0
# Scanned: LIFE // Trend: 1.555
# Scanned: LMAO // Trend: 0
# Scanned: LHDX // Trend: 0
# Scanned: LIZI // Trend: 0
# Scanned: LIXT // Trend: 0
# Scanned: LIVX // Trend: 0
# Scanned: LINC // Trend: 0
# Scanned: LIQT // Trend: 0
# Scanned: LHC // Trend: 0
# Scanned: LINK // Trend: 2.259
# Scanned: LFMD // Trend: 0
# Scanned: LFTR // Trend: 0
# Scanned: LCI // Trend: 0
# Scanned: LFT // Trend: 0
# Scanned: LEXX // Trend: 0
# Scanned: LGHL // Trend: 0
# Scanned: LFVN // Trend: 0
# Scanned: LGVN // Trend: 0
# Scanned: LCTX // Trend: 0
# Scanned: LEGA // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: LEJU // Trend: 0
# Scanned: LEDS // Trend: 0
# Scanned: KZR // Trend: 0
# Scanned: LBPS // Trend: 0
# Scanned: LAIX // Trend: 0
# Scanned: KURI // Trend: 0
# Scanned: KUKE // Trend: 0
# Scanned: KRMD // Trend: 0
# Scanned: KULR // Trend: 0
# Scanned: KVSA // Trend: 0
# Scanned: KXIN // Trend: 0
# Scanned: KZIA // Trend: 0
# Scanned: KTRA // Trend: 0
# Scanned: KNDI // Trend: 0
# Scanned: KRBP // Trend: 0
# Scanned: KSI // Trend: 0
# Scanned: KRNL // Trend: 0
# Scanned: KSMT // Trend: 0
# Scanned: KTCC // Trend: 0
# Scanned: KMPH // Trend: 11.947
# Stored 'stockDataFrame' (DataFrame)
# Scanned: KLXE // Trend: 0
# Scanned: KMF // Trend: 0
# Scanned: KMDA // Trend: 0
# Scanned: KOR // Trend: 0
# Scanned: KBNT // Trend: 0
# Scanned: KFS // Trend: 0
# Scanned: KFFB // Trend: 0
# Scanned: KRKR // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: KERN // Trend: 0
# Scanned: KALA // Trend: 0
# Scanned: JWEL // Trend: 0
# Scanned: KAVL // Trend: 0
#
# Your current ip-address is: 37.19.212.98
#
# Connecting you to united states ...
#
# your new ip-address is: 185.207.249.198
#
# Done! Enjoy your new server.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 185.207.249.198
#
# Connecting you to united states ...
#
# your new ip-address is: 185.207.249.184
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 185.207.249.184
#
# Connecting you to united states ...
#
# your new ip-address is: 83.136.182.30
#
# Done! Enjoy your new server.
#
# Scanned: JAGX // Trend: 0
# Scanned: JG // Trend: 0
# Scanned: JMM // Trend: 0
# Scanned: JCS // Trend: 0
# Scanned: JAN // Trend: 0
# Scanned: IVC // Trend: 0
# Scanned: ISSC // Trend: 0
# Scanned: ITRM // Trend: 1.689
# Scanned: IZEA // Trend: 0
# Scanned: IVAC // Trend: 0
# Scanned: IVAN // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ITI // Trend: 0
# Scanned: IRS // Trend: 0
# Scanned: ITP // Trend: 0
# Scanned: ISUN // Trend: 0
# Scanned: IRIX // Trend: 0
# Scanned: ISR // Trend: 0
# Scanned: ITRG // Trend: 0
# Scanned: IPDN // Trend: 0
# Scanned: ISLE // Trend: 0
# Scanned: ISOS // Trend: 0
# Scanned: ISPC // Trend: 0
# Scanned: INKA // Trend: 0
# Scanned: INVO // Trend: 0
# Scanned: INM // Trend: 0
# Scanned: IPA // Trend: 0
# Scanned: IPW // Trend: 0
# Scanned: IO // Trend: 0
# Scanned: INDO // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: INPX // Trend: 0
# Scanned: IMMP // Trend: 0
# Scanned: INUV // Trend: 0
# Scanned: INOD // Trend: 0
# Scanned: INFI // Trend: 7.321
# Scanned: IMUX // Trend: 0
# Scanned: INTZ // Trend: 0
# Scanned: IMMR // Trend: 0
# Scanned: IMV // Trend: 0
# Scanned: IMCC // Trend: 0
# Scanned: IMH // Trend: 0
# Scanned: IMRA // Trend: 0
# Scanned: IMTE // Trend: 0
# Scanned: III // Trend: 0
# Scanned: IMBI // Trend: 0
# Scanned: IKT // Trend: 0
# Scanned: IINN // Trend: 0
# Scanned: IMAC // Trend: 0
# Scanned: IH // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: IHT // Trend: 0
# Scanned: IFMK // Trend: 0
# Scanned: IGAC // Trend: 0
# Scanned: IGC // Trend: 0
# Scanned: ID // Trend: 0
# Scanned: ICCC // Trend: 0
# Scanned: IFBD // Trend: 0
# Scanned: IBIO // Trend: 0
# Scanned: IAF // Trend: 0
# Scanned: ICLK // Trend: 0
# Scanned: IGA // Trend: 0
# Scanned: ICMB // Trend: 0
# Scanned: HYMC // Trend: 0
# Scanned: HYAC // Trend: 0
# Scanned: ICON // Trend: 0
# Scanned: ICD // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: HUSN // Trend: 0
# Scanned: HYW // Trend: 0
# Scanned: HUIZ // Trend: 0
# Scanned: HUGE // Trend: 0
# Scanned: HUGS // Trend: 0
# Scanned: HX // Trend: 0
# Scanned: HUSA // Trend: 0
# Scanned: HZN // Trend: 0
# Scanned: HT // Trend: 0
# Scanned: HTBX // Trend: 0
# Scanned: HTGM // Trend: 0
# Scanned: HSTO // Trend: 0
# Scanned: HRTG // Trend: 0
# Scanned: HROW // Trend: 0
# Scanned: HOFV // Trend: 0
# Scanned: HOOK // Trend: 0
# Scanned: HNRG // Trend: 0
# Scanned: HMLP // Trend: 0
# Scanned: HOTH // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: HIO // Trend: 0
#
# Your current ip-address is: 83.136.182.30
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.213.148
#
# Done! Enjoy your new server.
#
# Scanned: HIHO // Trend: 0
# Scanned: HFFG // Trend: 0
# Scanned: HIGA // Trend: 0
# Scanned: HCWB // Trend: 0
# Scanned: HIL // Trend: 0
# Scanned: HEPA // Trend: 0
# Scanned: HGBL // Trend: 0
# Scanned: HGSH // Trend: 0
# Scanned: HGLB // Trend: 0
# Scanned: HDSN // Trend: 0
# Scanned: HCDI // Trend: 0
# Scanned: HCHC // Trend: 0
# Scanned: HCAQ // Trend: 0
# Scanned: HCCC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: HALL // Trend: 0
# Scanned: HBIO // Trend: 0
# Scanned: HARP // Trend: 0
# Scanned: HBP // Trend: 0
# Scanned: GWAC // Trend: 0
# Scanned: HAPP // Trend: 0
# Scanned: GWGH // Trend: 0
# Scanned: GURE // Trend: 0
# Scanned: GVP // Trend: 0
# Scanned: GUT // Trend: 0
# Scanned: GTE // Trend: 0
# Scanned: GTIM // Trend: 0
# Scanned: GTX // Trend: 0
# Scanned: GSMG // Trend: 0
# Scanned: GRVI // Trend: 0
# Scanned: GRTX // Trend: 0
# Scanned: GTEC // Trend: 0
# Scanned: GSIT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: GROM // Trend: 0
# Scanned: GRTS // Trend: 0
# Scanned: GRAY // Trend: 0
# Scanned: GRNQ // Trend: 0
# Scanned: GROW // Trend: 0
# Scanned: GSS // Trend: 0
# Scanned: GSV // Trend: 0
# Scanned: GROY // Trend: 0
# Scanned: GORO // Trend: 0
# Scanned: GPM // Trend: 0
# Scanned: GRF // Trend: 0
# Scanned: GOED // Trend: 0
# Scanned: GOBI // Trend: 0
# Scanned: GRIL // Trend: 0
# Scanned: GOVX // Trend: 0
# Scanned: GNUS // Trend: 1.709
# Scanned: GPL // Trend: 0
# Scanned: GNE // Trend: 0
# Scanned: GNSS // Trend: 0
# Scanned: GNFT // Trend: 0
# Scanned: GNT // Trend: 0
# Scanned: GNPX // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: GLYC // Trend: 0
# Scanned: GNLN // Trend: 0
# Scanned: GLTO // Trend: 0
# Scanned: GNCA // Trend: 0
# Scanned: GMBL // Trend: 0
# Scanned: GMDA // Trend: 0
# Scanned: GMTX // Trend: 0
# Scanned: GMVD // Trend: 0
# Scanned: GLG // Trend: 0
# Scanned: GLBS // Trend: 0
# Scanned: GLMD // Trend: 0
# Scanned: GMBT // Trend: 0
# Scanned: GLDG // Trend: 0
# Scanned: GLBL // Trend: 0
# Scanned: GIGM // Trend: 0
# Scanned: GHSI // Trend: 0
# Scanned: GIFI // Trend: 0
# Scanned: GIG // Trend: 0
# Scanned: GLOP // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: GEG // Trend: 0
# Scanned: GHAC // Trend: 0
# Scanned: GGT // Trend: 0
# Scanned: GFX // Trend: 0
# Scanned: GERN // Trend: 0
# Scanned: GEOS // Trend: 0
# Scanned: GCV // Trend: 0
# Scanned: GBR // Trend: 0
# Scanned: GASS // Trend: 0
# Scanned: GCAC // Trend: 0
# Scanned: GECC // Trend: 0
# Scanned: GENE // Trend: 0
# Scanned: GDL // Trend: 0
# Scanned: GBS // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: GAU // Trend: 0
# Scanned: GBOX // Trend: 0
# Scanned: GAME // Trend: 1.536
#
# Your current ip-address is: 37.19.213.148
#
# Connecting you to canada ...
#
# your new ip-address is: 162.253.71.39
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: FUND // Trend: 1.591
# Scanned: FVT // Trend: 0
# Scanned: FVE // Trend: 0
# Scanned: FWP // Trend: 0
# Scanned: FURY // Trend: 0
# Scanned: FUSN // Trend: 0
# Scanned: FTK // Trend: 0
# Scanned: FULC // Trend: 1.132
# Scanned: FTF // Trend: 0
# Scanned: FTEK // Trend: 0
# Scanned: FTFT // Trend: 0
# Scanned: FUSE // Trend: 0
# Scanned: FSEA // Trend: 0
# Scanned: FTRP // Trend: 0
# Scanned: FT // Trend: 4.256
# Scanned: FSRX // Trend: 0
# Scanned: FSII // Trend: 0
# Scanned: FSI // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: FRBK // Trend: 0
# Scanned: FRON // Trend: 0
# Scanned: FSTX // Trend: 0
# Scanned: FSSI // Trend: 0
# Scanned: FRSX // Trend: 0
# Scanned: FREQ // Trend: 0
# Scanned: FNHC // Trend: 0
# Scanned: FNCB // Trend: 0
# Scanned: FRLN // Trend: 0
# Scanned: FORD // Trend: 1.959
# Scanned: FPAY // Trend: 0
# Scanned: FORE // Trend: 0
# Scanned: FPL // Trend: 0
# Scanned: FOA // Trend: 0
# Scanned: FLUX // Trend: 0
# Scanned: FLGC // Trend: 0
# Scanned: FLMN // Trend: 0
# Scanned: FLXN // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: FLL // Trend: 0
# Scanned: FGB // Trend: 0
# Scanned: FHTX // Trend: 0
# Scanned: FLNT // Trend: 0
# Scanned: FHS // Trend: 0
# Scanned: FIXX // Trend: 0
# Scanned: FLAC // Trend: 0
# Scanned: FIV // Trend: 0
# Scanned: FGF // Trend: 0
# Scanned: FKWL // Trend: 0
# Scanned: FCRD // Trend: 0
# Scanned: FFHL // Trend: 0
# Scanned: FEDU // Trend: 0
# Scanned: FENG // Trend: 0
# Scanned: FF // Trend: 0
# Scanned: FACA // Trend: 0
# Scanned: FEMY // Trend: 0
# Scanned: FAMI // Trend: 0
# Scanned: FCO // Trend: 0
# Scanned: EZPW // Trend: 0
# Scanned: FACT // Trend: 1.648
# Stored 'stockDataFrame' (DataFrame)
# Scanned: EYEN // Trend: 0
# Scanned: EYPT // Trend: 0
# Scanned: EZGO // Trend: 0
# Scanned: EXTN // Trend: 0
# Scanned: EXN // Trend: 0
# Scanned: FARM // Trend: 1.698
# Scanned: FBIO // Trend: 0
# Scanned: EYES // Trend: 0
# Scanned: EVLO // Trend: 0
# Scanned: EVK // Trend: 0
# Scanned: EVFM // Trend: 0
# Scanned: EYEG // Trend: 0
# Scanned: EVOL // Trend: 0
# Scanned: EVGN // Trend: 0
# Scanned: EXPR // Trend: 0
# Scanned: EVOK // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: ETTX // Trend: 0
#
# Your current ip-address is: 162.253.71.39
#
# Connecting you to canada ...
#
# your new ip-address is: 66.115.145.77
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: EVC // Trend: 0
# Scanned: ERYP // Trend: 0
# Scanned: ERES // Trend: 0
# Scanned: EQS // Trend: 0
# Scanned: EQOS // Trend: 0
# Scanned: ESGC // Trend: 0
# Scanned: EVAX // Trend: 0
# Scanned: ENTX // Trend: 0
# Scanned: EOD // Trend: 0
# Scanned: ENZ // Trend: 0
# Scanned: EQ // Trend: 0
# Scanned: ENVB // Trend: 0
# Scanned: ENVI // Trend: 0
# Scanned: EPM // Trend: 0
# Scanned: ENG // Trend: 0
# Scanned: ENSC // Trend: 0
# Scanned: ENSV // Trend: 0
# Scanned: EPSN // Trend: 0
# Scanned: ENLV // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ELOX // Trend: 0
# Scanned: EMAN // Trend: 0
# Scanned: EMKR // Trend: 0
# Scanned: ELYS // Trend: 0
# Scanned: ENOB // Trend: 0
# Scanned: ELSE // Trend: 0
# Scanned: EMX // Trend: 0
# Scanned: EGY // Trend: 0
# Scanned: ELVT // Trend: 0
# Scanned: ELA // Trend: 0
# Scanned: ELEV // Trend: 0
# Scanned: EJH // Trend: 0
# Scanned: EKSO // Trend: 0
# Scanned: EEIQ // Trend: 0
# Scanned: EEX // Trend: 0
# Scanned: EDN // Trend: 0
# Scanned: EFOI // Trend: 0
# Scanned: EDSA // Trend: 0
# Scanned: EIGR // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: EAST // Trend: 1.636
# Scanned: EDF // Trend: 0
# Scanned: EDI // Trend: 0
# Scanned: EFL // Trend: 0
# Scanned: EBON // Trend: 0
# Scanned: EDAP // Trend: 0
# Scanned: EDTK // Trend: 0
# Scanned: DYNT // Trend: 0
# Scanned: DXF // Trend: 0
# Scanned: DVD // Trend: 0
# Scanned: ECOR // Trend: 0
# Scanned: DXYN // Trend: 0
# Scanned: EDD // Trend: 0
# Scanned: DYNS // Trend: 0
# Scanned: DWSN // Trend: 0
# Scanned: DUO // Trend: 0
# Scanned: DTSS // Trend: 0
# Scanned: DTST // Trend: 0
# Scanned: DUOT // Trend: 0
# Scanned: DSX // Trend: 0
# Scanned: DTEA // Trend: 0
# Scanned: DSWL // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: DSS // Trend: 0
# Scanned: DPW // Trend: 0
# Scanned: DSM // Trend: 0
# Scanned: DRTT // Trend: 0
# Scanned: DPRO // Trend: 0
# Scanned: DS // Trend: 0
# Scanned: DNAA // Trend: 0
# Scanned: DRRX // Trend: 0
# Scanned: DOGZ // Trend: 0
# Scanned: DOMA // Trend: 0
# Scanned: DMYI // Trend: 0
# Scanned: DMYQ // Trend: 0
# Scanned: DMAC // Trend: 0
# Scanned: DMS // Trend: 0
# Scanned: DLNG // Trend: 0
# Scanned: DMF // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: DGNS // Trend: 0
# Scanned: DHY // Trend: 0
# Scanned: DGLY // Trend: 0
# Scanned: DHF // Trend: 0
# Scanned: DHX // Trend: 0
# Scanned: DFNS // Trend: 0
# Scanned: DCTH // Trend: 0
# Scanned: DCF // Trend: 0
# Scanned: DFFN // Trend: 11.507
# Scanned: DCRC // Trend: 0
# Scanned: DDMX // Trend: 0
# Scanned: DEH // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 66.115.145.77
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.43
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CYCC // Trend: 0
# Scanned: CYAN // Trend: 0
# Scanned: CYTO // Trend: 0
# Scanned: CYCN // Trend: 0
# Scanned: CYTH // Trend: 0
# Scanned: CYRN // Trend: 0
# Scanned: CXE // Trend: 0
# Scanned: CYAD // Trend: 0
# Scanned: CXDC // Trend: 0
# Scanned: CUEN // Trend: 0
# Scanned: CVM // Trend: 0
# Scanned: CVU // Trend: 0
# Scanned: CVGI // Trend: 0
# Scanned: CXDO // Trend: 0
# Scanned: CUBA // Trend: 0
# Scanned: CVV // Trend: 0
# Scanned: CTIC // Trend: 0
# Scanned: CTK // Trend: 0
# Scanned: CTHR // Trend: 0
# Scanned: CTMX // Trend: 0
# Scanned: CWBR // Trend: 1.909
# Scanned: CTIB // Trend: 0
# Scanned: CTRM // Trend: 0
# Scanned: CTXR // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CTSO // Trend: 0
# Scanned: CSPR // Trend: 0
# Scanned: CTEK // Trend: 0
# Scanned: CTAC // Trend: 0
# Scanned: CSCW // Trend: 0
# Scanned: CSLT // Trend: 0
# Scanned: CRNT // Trend: 0
# Scanned: CRVS // Trend: 0
# Scanned: CRWS // Trend: 0
# Scanned: CRMD // Trend: 0
# Scanned: CRKN // Trend: 0
# Scanned: CTG // Trend: 0
# Scanned: CRTD // Trend: 0
# Scanned: CRU // Trend: 0
# Scanned: CREG // Trend: 0
# Scanned: CPSS // Trend: 0
# Scanned: CRBP // Trend: 0
# Scanned: CRESY // Trend: 0
# Scanned: CPSR // Trend: 0
# Scanned: CREX // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CPOP // Trend: 0
# Scanned: CPHI // Trend: 0
# Scanned: CPSH // Trend: 0
# Scanned: CPIX // Trend: 0
# Scanned: CPAR // Trend: 0
# Scanned: CRDF // Trend: 0
# Scanned: CORR // Trend: 0
# Scanned: COVA // Trend: 0
# Scanned: COMS // Trend: 0
# Scanned: COE // Trend: 0
# Scanned: COCP // Trend: 0
# Scanned: CODA // Trend: 0
# Scanned: COOL // Trend: 0
# Scanned: COGT // Trend: 0
# Scanned: CNSP // Trend: 0
# Scanned: CNCE // Trend: 0
# Scanned: CNEY // Trend: 0
# Scanned: CMU // Trend: 0
# Scanned: COLI // Trend: 0
# Scanned: CNET // Trend: 0
# Scanned: CNF // Trend: 0
# Scanned: CMCT // Trend: 0
# Scanned: CMPI // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CLSN // Trend: 0
# Scanned: CLXT // Trend: 0
# Scanned: CMCM // Trend: 0
# Scanned: CLWT // Trend: 0
# Scanned: CLRO // Trend: 0
# Scanned: CLSD // Trend: 0
# Scanned: CLVR // Trend: 0
# Scanned: CLRB // Trend: 0
# Scanned: CLEU // Trend: 0
# Scanned: CLBS // Trend: 0
# Scanned: CLIM // Trend: 0
# Scanned: CLPS // Trend: 0
# Scanned: CLPR // Trend: 0
# Scanned: CLAS // Trend: 0
# Scanned: CLIR // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: CIK // Trend: 0
# Scanned: CIDM // Trend: 0
# Scanned: CIA // Trend: 0
# Scanned: CKPT // Trend: 0
#
# Your current ip-address is: 37.19.212.43
#
# Connecting you to united states ...
#
# your new ip-address is: 83.136.182.61
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CIF // Trend: 0
# Scanned: CHEK // Trend: 0
# Scanned: CHNR // Trend: 0
# Scanned: CHCI // Trend: 0
# Scanned: CHMA // Trend: 0
# Scanned: CHMI // Trend: 0
# Scanned: CFV // Trend: 0
# Scanned: CFMS // Trend: 0
# Scanned: CERC // Trend: 0
# Scanned: CETX // Trend: 0
# Scanned: CFRX // Trend: 0
# Scanned: CGA // Trend: 0
# Scanned: CECE // Trend: 0
# Scanned: CDOR // Trend: 0
# Scanned: CDTX // Trend: 0
# Scanned: CEI // Trend: 0
# Scanned: CEMI // Trend: 0
# Scanned: CEPU // Trend: 0
# Scanned: CELP // Trend: 0
# Scanned: CGRN // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CBAT // Trend: 0
# Scanned: CBLI // Trend: 0
# Scanned: CCLP // Trend: 0
# Scanned: CCAC // Trend: 0
# Scanned: CCM // Trend: 0
# Scanned: CCNC // Trend: 0
# Scanned: CBAY // Trend: 0
# Scanned: CBIO // Trend: 0
# Scanned: CATB // Trend: 0
# Scanned: CADL // Trend: 0
# Scanned: CALA // Trend: 0
# Scanned: CASI // Trend: 0
# Scanned: CANF // Trend: 0
# Scanned: CAS // Trend: 0
# Scanned: CAPR // Trend: 0
# Scanned: CAHC // Trend: 0
# Scanned: CABA // Trend: 0
# Scanned: BYSI // Trend: 0
# Scanned: CAAS // Trend: 0
# Scanned: BXRX // Trend: 0
# Scanned: BWEN // Trend: 0
# Scanned: BYFC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BWAY // Trend: 0
# Scanned: BTB // Trend: 0
# Scanned: BSQR // Trend: 0
# Scanned: BVXV // Trend: 0
# Scanned: BTCM // Trend: 1.404
# Scanned: BTTR // Trend: 0
# Scanned: BTN // Trend: 0
# Scanned: BTAQ // Trend: 0
# Scanned: BRW // Trend: 0
# Scanned: BRN // Trend: 0
# Scanned: BRY // Trend: 0
# Scanned: BSGM // Trend: 0
# Scanned: BOSC // Trend: 0
# Scanned: BQ // Trend: 0
# Scanned: BPTS // Trend: 0
# Scanned: BPTH // Trend: 0
# Scanned: BORR // Trend: 0
# Scanned: BOXL // Trend: 0
# Scanned: BRCN // Trend: 0
# Scanned: BPT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BLU // Trend: 0
# Scanned: BMRA // Trend: 0
# Scanned: BNTC // Trend: 0
# Scanned: BNSO // Trend: 0
# Scanned: BNED // Trend: 0
# Scanned: BOAS // Trend: 0
# Scanned: BLTS // Trend: 0
# Scanned: BLCT // Trend: 0
# Scanned: BLIN // Trend: 0
# Scanned: BLRX // Trend: 0
# Scanned: BLPH // Trend: 0
# Scanned: BKTI // Trend: 0
# Scanned: BKYI // Trend: 0
# Scanned: BLCM // Trend: 0
# Scanned: BIOL // Trend: 0
# Scanned: BITE // Trend: 0
# Scanned: BKCC // Trend: 0
# Scanned: BKEP // Trend: 0
# Scanned: BKT // Trend: 0
# Scanned: BIOC // Trend: 0
# Scanned: BIMI // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: BHR // Trend: 0
# Scanned: BFRA // Trend: 0
# Scanned: BGIO // Trend: 0
# Scanned: BGI // Trend: 0
#
# Your current ip-address is: 83.136.182.61
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.144
#
# Done! Enjoy your new server.
#
# Scanned: BCTX // Trend: 0
# Scanned: BDR // Trend: 0
# Scanned: BDSI // Trend: 0
# Scanned: BDSX // Trend: 0
# Scanned: BCYP // Trend: 0
# Scanned: BEDU // Trend: 0
# Scanned: BDTX // Trend: 0
# Scanned: BEST // Trend: 1.401
# Scanned: BCTG // Trend: 0
# Scanned: BCDA // Trend: 0
# Scanned: BCLI // Trend: 0
# Scanned: BBGI // Trend: 0
# Scanned: BCEL // Trend: 0
# Scanned: BBIG // Trend: 0
# Scanned: BBI // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BAOS // Trend: 0
# Scanned: AZRX // Trend: 0
# Scanned: AYTU // Trend: 0
# Scanned: AXU // Trend: 0
# Scanned: AXTI // Trend: 0
# Scanned: BBCP // Trend: 0
# Scanned: AYRO // Trend: 0
# Scanned: AZYO // Trend: 0
# Scanned: AXDX // Trend: 0
# Scanned: AWRE // Trend: 0
# Scanned: AWX // Trend: 0
# Scanned: AXAS // Trend: 0
# Scanned: AVRO // Trend: 0
# Scanned: AVGR // Trend: 0
# Scanned: AVEO // Trend: 0
# Scanned: AXLA // Trend: 0
# Scanned: AVDL // Trend: 0
# Scanned: AUTO // Trend: 1.656
# Scanned: AUUD // Trend: 0
# Scanned: AURC // Trend: 0
# Scanned: AVCT // Trend: 0
# Scanned: AUTL // Trend: 0
# Scanned: AUVI // Trend: 0
# Scanned: AVCO // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: AUD // Trend: 0
# Scanned: AUMN // Trend: 0
# Scanned: ATHX // Trend: 0
# Scanned: ATNX // Trend: 0
# Scanned: ATHA // Trend: 0
# Scanned: ATXI // Trend: 0
# Scanned: ATOS // Trend: 1.958
# Scanned: ATIF // Trend: 0
# Scanned: ATA // Trend: 0
# Scanned: ASRT // Trend: 0
# Scanned: ASTC // Trend: 0
# Scanned: ATHE // Trend: 0
# Scanned: ATNF // Trend: 0
# Scanned: ATHN // Trend: 0
# Scanned: ASUR // Trend: 0
# Scanned: ASRV // Trend: 0
# Scanned: ASYS // Trend: 0
# Scanned: ASLN // Trend: 0
# Scanned: ASC // Trend: 0
# Scanned: ASMB // Trend: 0
# Scanned: ATAX // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ASM // Trend: 0
# Scanned: ASPS // Trend: 0
# Scanned: ASPU // Trend: 0
# Scanned: ASG // Trend: 0
# Scanned: ARDS // Trend: 0
# Scanned: ASAX // Trend: 0
# Scanned: ARTL // Trend: 0
# Scanned: AREC // Trend: 0
# Scanned: ARDX // Trend: 0
# Scanned: ARPO // Trend: 0
# Scanned: ARMP // Trend: 0
# Scanned: APTX // Trend: 0
# Scanned: APTO // Trend: 0
# Scanned: ARAV // Trend: 0
# Scanned: APWC // Trend: 0
# Scanned: ARAY // Trend: 0
# Scanned: AQST // Trend: 0
# Scanned: ARC // Trend: 6.562
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: AQMS // Trend: 0
# Scanned: APYX // Trend: 0
#
# Your current ip-address is: 37.19.212.144
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.213.18
#
# Done! Enjoy your new server.
#
# Scanned: APDN // Trend: 0
# Scanned: ANAC // Trend: 0
# Scanned: APM // Trend: 0
# Scanned: APEN // Trend: 0
# Scanned: APRE // Trend: 0
# Scanned: ANIX // Trend: 0
# Scanned: ANPC // Trend: 0
# Scanned: AMBO // Trend: 0
# Scanned: AMPG // Trend: 0
# Scanned: AMPE // Trend: 0
# Scanned: ALZN // Trend: 0
# Scanned: ALYA // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ALJJ // Trend: 0
# Scanned: ALT // Trend: 0
# Scanned: ALIM // Trend: 0
# Scanned: ALTO // Trend: 0
# Scanned: ALNA // Trend: 0
# Scanned: ALRN // Trend: 0
# Scanned: ALPN // Trend: 0
# Scanned: ALTU // Trend: 0
# Scanned: AIRI // Trend: 0
# Scanned: AIM // Trend: 0
# Scanned: AKTX // Trend: 0
# Scanned: AKTS // Trend: 0
# Scanned: AKBA // Trend: 0
# Scanned: AKU // Trend: 0
# Scanned: AIKI // Trend: 0
# Scanned: AGS // Trend: 0
# Scanned: AGRI // Trend: 0
# Scanned: AGRX // Trend: 0
# Scanned: AIHS // Trend: 0
# Scanned: AIH // Trend: 0
# Scanned: AGTC // Trend: 0
# Scanned: AHAC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: AEZS // Trend: 0
# Scanned: AFI // Trend: 0
# Scanned: AEY // Trend: 0
# Scanned: AGFS // Trend: 0
# Scanned: AGE // Trend: 1.112
# Scanned: AGLE // Trend: 0
# ...
# Scanned: CHFW // Trend: 0
# Scanned: CHNR // Trend: 0
# Scanned: CHMI // Trend: 0
# Scanned: CHMA // Trend: 0
# Scanned: CHEK // Trend: 0
# Scanned: CHCI // Trend: 0
# Scanned: CGA // Trend: 0
# Scanned: CFRX // Trend: 0
# Scanned: CFV // Trend: 0
# Scanned: CFMS // Trend: 0
# Scanned: CERC // Trend: 0
# Scanned: CGRN // Trend: 0
# Scanned: CETX // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: CDOR // Trend: 0
# Scanned: CDTX // Trend: 0
# Scanned: CEPU // Trend: 0
# Scanned: CELP // Trend: 0
# Scanned: CECE // Trend: 0
# Scanned: CEI // Trend: 0
# Scanned: CEMI // Trend: 0
# Scanned: CCNC // Trend: 0
# Scanned: CBAT // Trend: 0
# Scanned: CBLI // Trend: 0
# Scanned: CCLP // Trend: 0
# Scanned: CBAH // Trend: 0
# Scanned: CBAY // Trend: 0
# Scanned: CCAC // Trend: 0
# Scanned: CBIO // Trend: 0
# Scanned: CCM // Trend: 0
# Scanned: CAS // Trend: 0
# Scanned: CAHC // Trend: 0
# Scanned: CALA // Trend: 0
# Scanned: CAPR // Trend: 0
# Scanned: CADL // Trend: 0
# Scanned: CASI // Trend: 0
# Scanned: CATB // Trend: 0
# Scanned: CANF // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BXRX // Trend: 0
# Scanned: CABA // Trend: 0
# Scanned: BYSI // Trend: 0
# Scanned: BWAY // Trend: 0
# Scanned: CAAS // Trend: 0
# Scanned: BYFC // Trend: 0
# Scanned: BWEN // Trend: 0
# Scanned: BSQR // Trend: 0
# Scanned: BTN // Trend: 0
# Scanned: BVXV // Trend: 0
# Scanned: BTTR // Trend: 0
# Scanned: BRY // Trend: 0
# Scanned: BTAQ // Trend: 0
# Scanned: BTB // Trend: 0
# Scanned: BORR // Trend: 0
# Scanned: BSGM // Trend: 0
# Scanned: BRN // Trend: 0
# Scanned: BOXL // Trend: 0
# Scanned: BRW // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: BRCN // Trend: 0
# Scanned: BPTS // Trend: 0
# Scanned: BNTC // Trend: 0
# Scanned: BQ // Trend: 0
#
# Your current ip-address is: 185.207.249.137
#
# Connecting you to united states ...
#
# your new ip-address is: 83.136.182.55
#
# Done! Enjoy your new server.
#
# Scanned: BOAS // Trend: 0
# Scanned: BNSO // Trend: 0
# Scanned: BNED // Trend: 0
# Scanned: BLTS // Trend: 0
# Scanned: BLU // Trend: 0
# Scanned: BKTI // Trend: 0
# Scanned: BLRX // Trend: 0
# Scanned: BLPH // Trend: 0
# Scanned: BKYI // Trend: 0
# Scanned: BITE // Trend: 0
# Scanned: BLCT // Trend: 0
# Scanned: BLIN // Trend: 0
# Scanned: BLCM // Trend: 0
# Scanned: BIOL // Trend: 8.636
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BKEP // Trend: 0
# Scanned: BGI // Trend: 0
# Scanned: BHSE // Trend: 0
# Scanned: BKCC // Trend: 0
# Scanned: BIOT // Trend: 0
# Scanned: BKT // Trend: 0
# Scanned: BIMI // Trend: 0
# Scanned: BIOC // Trend: 0
# Scanned: BHAT // Trend: 0
# Scanned: BFRA // Trend: 0
# Scanned: BCTX // Trend: 0
# Scanned: BHTG // Trend: 0
# Scanned: BGIO // Trend: 0
# Scanned: BHR // Trend: 0
# Scanned: BGR // Trend: 0
# Scanned: BDR // Trend: 0
# Scanned: BDTX // Trend: 0
# Scanned: BCTG // Trend: 0
# Scanned: BDSI // Trend: 0
# Scanned: BDSX // Trend: 0
# Scanned: BEDU // Trend: 0
# Scanned: BCDA // Trend: 0
# Scanned: BCAC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BCEL // Trend: 0
# Scanned: AXTI // Trend: 0
# Scanned: BBI // Trend: 0
# Scanned: BBCP // Trend: 0
# Scanned: BBGI // Trend: 0
# Scanned: BAOS // Trend: 0
# Scanned: BCLI // Trend: 0
# Scanned: BBIG // Trend: 1.712
# Scanned: AXDX // Trend: 0
# Scanned: AZRX // Trend: 0
# Scanned: AYTU // Trend: 0
# Scanned: AXU // Trend: 0
# Scanned: AYRO // Trend: 0
# Scanned: AWX // Trend: 0
# Scanned: AZYO // Trend: 0
# Scanned: AVEO // Trend: 0
# Scanned: AXLA // Trend: 0
# Scanned: AVGR // Trend: 0
# Grabbing new access token...
# Scanned: AUVI // Trend: 0
# Scanned: AWRE // Trend: 0
# Scanned: AXAS // Trend: 0
# Scanned: AVRO // Trend: 0
# Scanned: AVCO // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: AUUD // Trend: 0
# Scanned: AUD // Trend: 0
# Scanned: ATXI // Trend: 0
# Scanned: AUMN // Trend: 0
# Scanned: AVCT // Trend: 0
# Scanned: AVDL // Trend: 0
# Scanned: AUTL // Trend: 0
# Scanned: ATHE // Trend: 0
# Scanned: ATHA // Trend: 0
# Scanned: ATNX // Trend: 0
# Scanned: ATHX // Trend: 0
# Scanned: ATNF // Trend: 6.477
# Scanned: ATIF // Trend: 0
# Scanned: ASUR // Trend: 0
# Scanned: ASTC // Trend: 0
# Scanned: ASRV // Trend: 0
# Scanned: ASYS // Trend: 0
# Scanned: ATAX // Trend: 0
# Scanned: ATA // Trend: 0
# Scanned: ASRT // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: ASLN // Trend: 0
# Scanned: ASPS // Trend: 0
# Scanned: ASM // Trend: 0
#
# Your current ip-address is: 83.136.182.55
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.194
#
# Done! Enjoy your new server.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 37.19.212.194
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.60
#
# Done! Enjoy your new server.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 37.19.212.60
#
# Connecting you to united states ...
#
# your new ip-address is: 185.207.249.182
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: APRN // Trend: 0
# Scanned: APTX // Trend: 0
# Scanned: ANY // Trend: 0
# Scanned: APYX // Trend: 0
# Scanned: AQMS // Trend: 0
# Scanned: APWC // Trend: 0
# Scanned: AQB // Trend: 0
# Scanned: APOP // Trend: 0
# Scanned: APDN // Trend: 0
# Scanned: APRE // Trend: 0
# Scanned: AP // Trend: 0
# Scanned: ANTE // Trend: 0
# Scanned: ANPC // Trend: 0
# Scanned: APEN // Trend: 0
# Scanned: APM // Trend: 0
# Scanned: AMPE // Trend: 0
# Scanned: ANIX // Trend: 0
# Scanned: AMPG // Trend: 0
# Scanned: AMBO // Trend: 0
# Scanned: ANAC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ALTO // Trend: 0
# Scanned: ALRN // Trend: 0
# Scanned: ALIM // Trend: 0
# Scanned: ALZN // Trend: 0
# Scanned: ALTU // Trend: 0
# Scanned: ALJJ // Trend: 0
# Scanned: ALNA // Trend: 0
# Scanned: ALYA // Trend: 0
# Scanned: AIKI // Trend: 0
# Scanned: AIRI // Trend: 0
# Scanned: AKBA // Trend: 0
# Scanned: AKTS // Trend: 0
# Scanned: ALT // Trend: 0
# Scanned: AKU // Trend: 0
# Scanned: ALPN // Trend: 0
# Scanned: AHAC // Trend: 0
# Scanned: AIM // Trend: 0
# Scanned: AGS // Trend: 0
# Scanned: AIH // Trend: 0
# Scanned: AIHS // Trend: 0
# Scanned: AGRI // Trend: 0
# Scanned: AGRX // Trend: 0
# Scanned: AKTX // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: AGFS // Trend: 0
# Scanned: AFI // Trend: 0
# Scanned: AGLE // Trend: 0
# Scanned: AGTC // Trend: 0
# Scanned: AEZS // Trend: 0
# Scanned: AGMH // Trend: 0
# Scanned: AENZ // Trend: 0
# Scanned: AEF // Trend: 0
# Scanned: AESE // Trend: 0
# Scanned: AEI // Trend: 0
# Scanned: AEHR // Trend: 0
# Scanned: AEHL // Trend: 0
# Scanned: AEY // Trend: 0
# Scanned: ADTX // Trend: 0
# Scanned: AEMD // Trend: 0
# Scanned: ADXS // Trend: 0
# Scanned: ADVM // Trend: 0
# Scanned: ADN // Trend: 0
# Scanned: ADMS // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ADEX // Trend: 0
# Scanned: ADF // Trend: 0
# Scanned: ADMA // Trend: 0
# Scanned: ADMP // Trend: 0
# Scanned: ADES // Trend: 0
# Scanned: ADIL // Trend: 0
# Scanned: ACXP // Trend: 0
# Scanned: ACEV // Trend: 0
# Scanned: ACRX // Trend: 0
# Scanned: ACTD // Trend: 0
# Scanned: ACOR // Trend: 0
# Scanned: ACST // Trend: 0
# Scanned: ACTG // Trend: 0
# Scanned: ACHV // Trend: 0
# Scanned: ACET // Trend: 0
# Scanned: ABIO // Trend: 0
# Scanned: ABVC // Trend: 0
# Scanned: ACER // Trend: 0
# Scanned: ABUS // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: AAOI // Trend: 0
# Scanned: AACG // Trend: 0
# Scanned: AAU // Trend: 0
# Scanned: AAME // Trend: 0
# Scanned: AATC // Trend: 0
# Scanned: ABEO // Trend: 0
# Scanned: AAIC // Trend: 0
# Scanned: YVR // Trend: 0
# Scanned: ZSAN // Trend: 0
# Scanned: ZYNE // Trend: 0
# Scanned: ZIXI // Trend: 0
# Scanned: YTRA // Trend: 0
# Scanned: ZVO // Trend: 0
# Scanned: ZKIN // Trend: 0
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: VHAQ // Trend: 0
# Scanned: VERY // Trend: 0
# Scanned: VENA // Trend: 0
#
# Your current ip-address is: 185.207.249.182
#
# Connecting you to united states ...
#
# your new ip-address is: 83.136.182.80
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: TARA // Trend: 0
# Scanned: TANH // Trend: 0
# Scanned: TATT // Trend: 0
# Scanned: TBLT // Trend: 0
# Scanned: TAST // Trend: 0
# Scanned: TEDU // Trend: 0
# Scanned: TAOP // Trend: 0
# Scanned: SLDB // Trend: 0
# Scanned: SINT // Trend: 0
# Scanned: SLNG // Trend: 0
# Scanned: SIGA // Trend: 0
# Scanned: SLGG // Trend: 0
# Scanned: SIEB // Trend: 0
# Scanned: QUMU // Trend: 0
# Scanned: QUBT // Trend: 0
# Scanned: QTT // Trend: 0
# Scanned: RCG // Trend: 0
# Scanned: RAVE // Trend: 0
# Scanned: QUAD // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: PCTI // Trend: 0
# Scanned: PESI // Trend: 0
# Scanned: PCYG // Trend: 0
# Scanned: PCK // Trend: 0
# Scanned: PDOT // Trend: 0
# Scanned: PCSA // Trend: 0
# Scanned: PED // Trend: 0
# Scanned: PCF // Trend: 0
# Scanned: NEPH // Trend: 0
# Scanned: NGC // Trend: 0
# Scanned: NEPT // Trend: 0
# Scanned: NES // Trend: 0
# Scanned: NEXT // Trend: 0
# Scanned: NBY // Trend: 0
# Scanned: NGAC // Trend: 0
# Scanned: LPCN // Trend: 0
# Scanned: LQDA // Trend: 0
# Scanned: LPTX // Trend: 0
# Scanned: LPTH // Trend: 0
# Scanned: LOV // Trend: 0
# Scanned: LOGC // Trend: 0
# Scanned: LOKB // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: IVAN // Trend: 0
# Scanned: ITI // Trend: 0
# Scanned: ITRG // Trend: 0
# Scanned: ISUN // Trend: 0
# Scanned: IVAC // Trend: 0
# Scanned: ITP // Trend: 0
# Scanned: ISSC // Trend: 0
# Scanned: HOFV // Trend: 0
# Scanned: HMLP // Trend: 0
# Scanned: HJLI // Trend: 0
# Scanned: HNNA // Trend: 0
# Scanned: HITI // Trend: 0
# Scanned: HIO // Trend: 0
# Scanned: HIHO // Trend: 0
# Scanned: HIL // Trend: 0
# Scanned: HIGA // Trend: 0
# Scanned: HGBL // Trend: 0
# Scanned: HGSH // Trend: 0
# Scanned: HIX // Trend: 0
# Scanned: HCWB // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: HCAQ // Trend: 0
# Scanned: HEPA // Trend: 0
# Scanned: HDSN // Trend: 0
# Scanned: HCCC // Trend: 0
# Scanned: HGLB // Trend: 0
# Scanned: HCDI // Trend: 0
# Scanned: HFFG // Trend: 0
# Scanned: HARP // Trend: 0
# Scanned: HCHC // Trend: 0
# Scanned: HCIC // Trend: 0
# Scanned: HALL // Trend: 0
# Scanned: GWAC // Trend: 0
# Scanned: HBP // Trend: 0
# Scanned: FTFT // Trend: 0
# Scanned: FTEK // Trend: 0
# Scanned: FTRP // Trend: 0
# Scanned: FTK // Trend: 0
# Scanned: FTF // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: EPM // Trend: 0
# Scanned: ENSV // Trend: 0
# Your current ip-address is: 83.136.182.80
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.98
#
# Done! Enjoy your new server.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
#
# Your current ip-address is: 37.19.212.98
#
# Connecting you to canada ...
#
# your new ip-address is: 37.19.212.194
#
# Done! Enjoy your new server.
#
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# The request failed: Google returned a response with code 429.
# Scanned: BRCN // Trend: 0
# Scanned: BOSC // Trend: 0
#
# Your current ip-address is: 37.19.212.194
#
# Connecting you to united states ...
#
# your new ip-address is: 185.207.249.18
#
# Done! Enjoy your new server.
#
# Stored 'stockDataFrame' (DataFrame)
# Scanned: ASPS // Trend: 0
# Scanned: ASC // Trend: 0
# Scanned: ASM // Trend: 0
# Scanned: ASPU // Trend: 0
# Scanned: ASMB // Trend: 0
# Scanned: ASG // Trend: 0
# Scanned: ASLN // Trend: 0
# Scanned: ARTL // Trend: 0
# Scanned: ARDS // Trend: 0
# Scanned: ASAX // Trend: 0
# Scanned: ARPO // Trend: 0
# Scanned: ARYE // Trend: 0
# Scanned: APTO // Trend: 0
# Scanned: ARAV // Trend: 0
# Scanned: ARDX // Trend: 0
# Scanned: AQST // Trend: 0
# Scanned: ARAY // Trend: 0
# Scanned: AREC // Trend: 0
# Scanned: ARMP // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: VERY // Trend: 0
# Scanned: VCNX // Trend: 0
# Scanned: VHAQ // Trend: 0
# Scanned: VERB // Trend: 0
# Scanned: VGZ // Trend: 0
# Scanned: VELO // Trend: 0
# Scanned: VERO // Trend: 0
# Scanned: VENA // Trend: 0
# Scanned: ENSV // Trend: 0
# Scanned: EPM // Trend: 0
# Scanned: ENVB // Trend: 0
# Scanned: EPSN // Trend: 0Scanned: ENVI // Trend: 0
#
# Scanned: ENG // Trend: 0
# Scanned: CRDF // Trend: 0
# Scanned: CPSR // Trend: 0
# Scanned: CRBP // Trend: 0
# Scanned: CREG // Trend: 0
# Scanned: CREX // Trend: 0
# Scanned: CRESY // Trend: 0
# Scanned: CPSS // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
# Scanned: BPTH // Trend: 0
# Scanned: BPTS // Trend: 0
# Scanned: BQ // Trend: 0
# Scanned: BOSC // Trend: 0
# Scanned: BMRA // Trend: 0
# Scanned: BRCN // Trend: 0
# Scanned: BPT // Trend: 0
# Scanned: BNTC // Trend: 0
# Stored 'stockDataFrame' (DataFrame)
#
# The program took 12.37 minutes to run.
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Disconnecting...
# Done!
# Using timeframe (now 1-d)
#
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Disconnecting...
# Done!
# ...From the current VPN connection...
#
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Saving settings in project folder...
#
#
# Done!
#
#
# Your current ip-address is: 69.136.101.196
#
# Connecting you to united states ...
#
# your new ip-address is: 212.102.44.53
#
# Done! Enjoy your new server.
#
# Initializing program...
# Program initialized.
# Found 1736 tickers!
#
# Multiple runs... modifying objects
# Scanned: SQNS // Trend: 0
# Scanned: BIOL // Trend: 0
# Scanned: SEAC // Trend: 0
# Scanned: MITQ // Trend: 0
# Scanned: FLUX // Trend: 0
# Scanned: PAYS // Trend: 0
# Scanned: ATNF // Trend: 3.777
# Scanned: LITB // Trend: 11.132
# Scanned: PTN // Trend: 0
# Scanned: ENLV // Trend: 0
# Scanned: GLOP // Trend: 0
# Scanned: ACHL // Trend: 2.105
# Scanned: FT // Trend: 0
# Scanned: WHLM // Trend: 4.579
# Scanned: DYAI // Trend: 2.711
# Scanned: MOGO // Trend: 2.22
# Scanned: BTCM // Trend: 2.173
# Scanned: CVM // Trend: 0
