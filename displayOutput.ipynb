# %%
import time
import pandas as pd
from IPython.display import clear_output
import copy
import winsound

# %%
# read the data frame variable
# %store -r stockDataFrame
# display it before the loop
display(stockDataFrame.head(50))


# run forever
while True:
    
    # two variables that are compared
    # check to see if there is any change
    frameCopy = copy.deepcopy(stockDataFrame)
    # %store -r stockDataFrame
    
    # small delay
    time.sleep(3)
    
    # waits for the data frame to update
    # when it does it executes the following
    if frameCopy.values.tolist() != stockDataFrame.values.tolist():
        
        # beep to alert user of the change
#         winsound.Beep(700, 750)
        
        clear_output(wait=True)
        display(stockDataFrame.head(50))
# Out:
#    tickerSymbol trendPriceRelationship  currentTrend  previousTrend  \
# 0          SQNS                    N/A        48.077          0.000
# 1          SEAC                    N/A        31.348          0.000
# 2          FLUX                    N/A        20.040          0.000
# 3          LITB                  243.8        16.667         23.981
# 4          MITQ                    N/A        12.847          0.000
# 5          BIOL                    N/A         8.636          0.000
# 6          ATNF                    N/A         6.477          0.000
# 7          PAYS                    N/A         5.721          0.000
# 8          WHLM                    N/A         5.016          5.066
# 9           PTN                    N/A         3.460          0.000
# 10         GLOP                    N/A         3.198          0.000
# 11         ACHL                    N/A         3.066          1.176
# 12         DYAI                  162.4         3.060          4.684
# ...
